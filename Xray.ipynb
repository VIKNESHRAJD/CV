# %% [markdown]
# # VIKNESHRAJ D
# # 122012173030

# %% [markdown]
# # QUESTION 1: EDGE DETECTION IN X-RAY IMAGES

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('xray.jpeg')
img = cv.cvtColor(img,cv.COLOR_RGB2BGR)

# %%
plt.imshow(img)
plt.axis("off")
plt.title("Ribcage")
plt.show()

# %% [markdown]
# # READ THE IMAGE

# %%
img = cv.imread('xray.jpeg')
plt.imshow(img)

# %%
img = cv.cvtColor(img,cv.COLOR_RGB2BGR)

# %%
sobelX = cv.Sobel(img,cv.CV_64F,1,0)

# %%
sobelY = cv.Sobel(img,cv.CV_64F,0,1)

# %%
sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))

# %%
combined = cv.bitwise_or(sobelX,sobelY)

# %% [markdown]
# # LAPLACIAN OPERATOR

# %%
lab = cv.Laplacian(img,cv.CV_64F,ksize = 3)
lab = np.uint8(np.absolute(lab))

# %% [markdown]
# # DISPLAY RESULT

# %%
titles = ['image','Combined','Laplacian']
images = [img,combined,lab]

for i in range(3):
    plt.subplot(2,3,i+1),plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

# %%
cv.imshow('combined',combined)
cv.imshow('lab',lab)
cv.imwrite('combined.jpeg',combined)
cv.imwrite('laplacian.jpeg',lab)

cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:7c910571-7e51-4721-9154-e35ff44d1fe1.png)
